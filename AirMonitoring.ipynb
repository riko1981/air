# %% [markdown]
# # AirVision - ?????????? ???????? ???????
#
# ?????? ??????????? ?? ??????????? ????? `.venv`. ????????? SQL Server ? API ??????? ?? `.env` ??? ?? ???????? ?? ????????? ? ????.

# %%
# %pip install -r requirements.txt

# %%
from main import app
app.title
